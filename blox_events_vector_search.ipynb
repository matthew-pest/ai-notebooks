# %% [markdown]
# # Netflix recommendations

# %% [markdown]
# <div class="alert alert-block alert-warning">
# Replace <code>YOUR_GITHUB_TOKEN</code> in the install script. To get your token follow the instructions in the <a href="../README.md">README.md</a>
# </div>

# %% [markdown]
# ## Boilerplate

# %%
# %pip install pandas
from google.colab import userdata
github_token = userdata.get('github_token')
url = f"https://us-central1-data-359211.cloudfunctions.net/github-proxy/superlinked-0.1.0-py3-none-any.whl?token={github_token}"
# !pip install "$url"
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Collecting superlinked==0.1.0
#   Downloading https://us-central1-data-359211.cloudfunctions.net/github-proxy/superlinked-0.1.0-py3-none-any.whl?token=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 (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 kB 59.8 MB/s eta 0:00:00
# Collecting jsonpath-ng (from superlinked==0.1.0)
#   Downloading jsonpath_ng-1.6.0-py3-none-any.whl (29 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from superlinked==0.1.0) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from superlinked==0.1.0) (1.5.3)
# Collecting sentence-transformers (from superlinked==0.1.0)
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from superlinked==0.1.0) (4.5.0)
# Collecting ply (from jsonpath-ng->superlinked==0.1.0)
#   Downloading ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->superlinked==0.1.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->superlinked==0.1.0) (2023.3.post1)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->superlinked==0.1.0) (4.35.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->superlinked==0.1.0) (4.66.1)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->superlinked==0.1.0) (2.1.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->superlinked==0.1.0) (0.16.0+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->superlinked==0.1.0) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->superlinked==0.1.0) (1.11.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->superlinked==0.1.0) (3.8.1)
# Collecting sentencepiece (from sentence-transformers->superlinked==0.1.0)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->superlinked==0.1.0) (0.19.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers->superlinked==0.1.0) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers->superlinked==0.1.0) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers->superlinked==0.1.0) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers->superlinked==0.1.0) (6.0.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers->superlinked==0.1.0) (23.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->superlinked==0.1.0) (1.16.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers->superlinked==0.1.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers->superlinked==0.1.0) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers->superlinked==0.1.0) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers->superlinked==0.1.0) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers->superlinked==0.1.0) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers->superlinked==0.1.0) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers->superlinked==0.1.0) (0.4.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers->superlinked==0.1.0) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers->superlinked==0.1.0) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers->superlinked==0.1.0) (3.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers->superlinked==0.1.0) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers->superlinked==0.1.0) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers->superlinked==0.1.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers->superlinked==0.1.0) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers->superlinked==0.1.0) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers->superlinked==0.1.0) (2023.11.17)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers->superlinked==0.1.0) (1.3.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=33126252da8492f41ddd2bc7c97d2f04ee87210fccef01f10cfe105b9c9220bc
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: sentencepiece, ply, jsonpath-ng, sentence-transformers, superlinked
# Successfully installed jsonpath-ng-1.6.0 ply-3.11 sentence-transformers-2.2.2 sentencepiece-0.1.99 superlinked-0.1.0

# %% [markdown]
# ## Imports and constants

# %%
import pandas as pd
from datetime import datetime, timezone
import pytz

from superlinked.framework.common.dag.recency_node import PeriodTimeParam
from superlinked.framework.common.schema.schema import schema, String, Timestamp, IdField, Integer
from superlinked.framework.common.parser.dataframe_parser import DataFrameParser
from superlinked.framework.dsl.executor.in_memory.in_memory_executor import InMemoryExecutor, InMemoryApp
from superlinked.framework.dsl.index.index import Index
from superlinked.framework.dsl.query.param import Param
from superlinked.framework.dsl.query.query import Query
from superlinked.framework.dsl.query.result import Result
from superlinked.framework.dsl.source.in_memory_source import InMemorySource
from superlinked.framework.dsl.space.text_similarity_space import TextSimilaritySpace
from superlinked.framework.dsl.space.recency_space import RecencySpace

# %%
MODEL = "sentence-transformers/paraphrase-MiniLM-L3-v2"
YEAR_IN_DAYS = 365
TOP_N = 10

# %% [markdown]
# ### Helpers

# %%
def get_ordered_result_tuples(result: Result, top_n: int) -> list[tuple[int]]:
    return [(i+1, int(entity.id_.object_id)) for i, entity in enumerate(result.entities[:top_n])]

def get_events_by_id_list(id_list_tuple: list[tuple[int]], df: pd.DataFrame) -> pd.DataFrame:
    if df.index.name != "id":
        df = df.set_index("id")
    result_df = df.loc[[id_tuple[1] for id_tuple in id_list_tuple]]
    print(result_df)
    result_df["order"] = [id_tuple[0] for id_tuple in id_list_tuple]
    return result_df

def parse_results(result: Result, df: pd.DataFrame, top_n: int = TOP_N) -> pd.DataFrame:
    id_tuples = get_ordered_result_tuples(result=result, top_n=top_n)
    return get_events_by_id_list(id_list_tuple=id_tuples, df=df)

def datetimestr_to_epoch(date_str):
    # Parse the date string to a datetime object
    dt = datetime.strptime(date_str, "%Y-%m-%dT%H:%M:%S.%fZ")
    # Convert the datetime object to UTC timezone
    dt = dt.replace(tzinfo=timezone.utc)
    # Get the total seconds since Unix Epoch
    epoch_time = (dt - datetime(1970, 1, 1, tzinfo=timezone.utc)).total_seconds()
    return epoch_time

def datestr_to_epoch(date_str):
    # Parse the date string to a datetime object without time information
    dt = datetime.strptime(date_str, "%Y-%m-%d")
    # Localize the datetime object to UTC timezone
    utc_tz = pytz.utc
    dt = utc_tz.localize(dt)
    # Get the total seconds since Unix Epoch
    epoch_time = (dt - datetime(1970, 1, 1, tzinfo=utc_tz)).total_seconds()
    return epoch_time

# %% [markdown]
# ## Explore dataset

# %%
event_df = pd.read_csv("/content/blox-event-table-data.csv")
event_df = event_df.fillna('')
event_df = event_df[['id', 'date_created', 'date_modified', 'slug', 'date', 'age_limit', 'image', 'venue_id', 'description', 'time1', 'time2', 'time1_type_id', 'time2_type_id', 'private', 'venue_undisclosed', 'title', 'sale_ended', 'metadata_image', 'draft', 'release_date', 'creator_id', 'last_modifier_id', 'white_label_only', 'deleted', 'artist_names', 'promoter_names', 'organization_names', 'club_name', 'club_address', 'creator_email', 'modifier_email']].dropna(how='any', subset=['id'])
event_df['id'] = event_df["id"]
event_df['date_created'] = event_df["date_created"].apply(datetimestr_to_epoch)
event_df['date_modified'] = event_df["date_modified"].apply(datetimestr_to_epoch)
event_df['date'] = event_df["date"].apply(datestr_to_epoch)
event_df.head()
print(event_df)
# Out:
#        id  date_created  date_modified  \
# 0       1  1.642705e+09   1.643230e+09
# 1       2  1.567641e+09   1.583939e+09
# 2       3  1.567792e+09   1.579149e+09
# 3       4  1.567793e+09   1.583939e+09
# 4       5  1.567793e+09   1.583939e+09
# ..    ...           ...            ...
# 843  1125  1.699896e+09   1.699902e+09
# 844  1134  1.700099e+09   1.700099e+09
# 845  1135  1.700157e+09   1.700157e+09
# 846  1138  1.700428e+09   1.700442e+09
# 847  1140  1.700632e+09   1.700633e+09
#
#                                          slug          date  age_limit  \
# 0                       primary-presents-melt  1.643328e+09         21
# 1    overdrive-w-agent-orange-dj-gettoblaster  1.569629e+09         21
# 2               proper-presents-dave-owen-nyc  1.568160e+09         21
# 3                  proper-presents-rees-urban  1.568765e+09         21
# 4                     proper-presents-dave-uv  1.569370e+09         21
# ..                                        ...           ...        ...
# 843                         sky-high-nye-2024  1.703981e+09         21
# 844                            pat-leary-trio  1.700006e+09         21
# 845      tied-presents-noha-live-max-jacobson  1.700179e+09         21
# 846                               durty-truth  1.701475e+09         21
# 847       dimibowie-presents-julie-marghilano  1.702598e+09         21
#
#                                          image  venue_id  \
# 0        b76bf91eec1c5fe04b9d30981a74695d.jpeg        61
# 1        ed117609e87f01027f8e5e8f42fd5210.jpeg         2
# 2         5b7e15182a85c09ff5beedacfcf72d4e.jpg        22
# 3         db417771f0fce4dab1b8a4653aed20f9.jpg        22
# 4         36a455e07f542065f891e807885b0189.jpg        22
# ..                                         ...       ...
# 843   d783709a-a69b-429e-acd2-b2d3a4f9b6b8.jpg         4
# 844     ME584e6038daeedadc2b07a19fefbe4a5a.jpg       142
# 845   f3f19864-a8bd-4807-aebe-6ff21ee2ac0d.jpg        50
# 846  f7ad23ed-a3da-41ba-b906-c3c67f1ec99b.jpeg       314
# 847   3e1f99a0-dc6f-4d10-b634-d9ba7ce6ac0c.png       288
#
#                                            description     time1  ...  \
# 0                                                       22:00:00  ...
# 1    Let us take you on cruise control through a vi...  23:00:00  ...
# 2                                                       21:00:00  ...
# 3                                                       21:00:00  ...
# 4                                                       21:00:00  ...
# ..                                                 ...       ...  ...
# 843  Come welcome in the New Year up in the clouds ...  21:00:00  ...
# 844  Experience an unforgettable night with the Pat...  20:00:00  ...
# 845  We welcome Noha for a special live set! With r...  22:00:00  ...
# 846  Legends Traxx & Darryn Jones on a serious syst...  22:00:00  ...
# 847  Julie Marghilano // SOL ASYLUM\nJulie Marghila...  22:00:00  ...
#
#     last_modifier_id  white_label_only deleted  \
# 0                  2             False   False
# 1                  2             False   False
# 2                  2              True   False
# 3                  2             False   False
# 4                  2              True   False
# ..               ...               ...     ...
# 843             7986             False   False
# 844             7865             False   False
# 845             7918             False   False
# 846             7865             False   False
# 847              218             False   False
#
#                                           artist_names  \
# 0        Arvii Mala, John Stuart, L3XX, Ladiesman, Stu
# 1    Agent Orange DJ, Aliens (debut), Blu 9, Charli...
# 2                Chrissy T, Dave Owen, J Cross, Misfit
# 3    Audiophlex, Rees Urban, Scrimshaw, Sleepy Sele...
# 4    Alcove, Dave UV, Killa Kutz, Mega Mike, Occum'...
# ..                                                 ...
# 843  Brady Prince, Dom Brown, MZ WORTHY, Psycho B!t...
# 844                                     Pat Leary Trio
# 845                                 Max Jacobson, Noha
# 846                               Darryn Jones , Traxx
# 847  Double Dipp, Julie Marghilano, Mantas Steles, ...
#
#                           promoter_names   organization_names  \
# 0    Primary Nightclub, Primary Presents   Primary Night Club
# 1                                             Twist and Fader
# 2                         Proper Chicago  Proper Chicago Temp
# 3                         Proper Chicago  Proper Chicago Temp
# 4                         Proper Chicago  Proper Chicago Temp
# ..                                   ...                  ...
# 843           Dom Brown, Organized Grime      Organized Grime
# 844                         Relax Attack              XXXXXXX
# 845                                 Tied                 Tied
# 846                                                  Material
# 847                            DIMIBOWIE            Dimibowie
#
#                                        club_name  \
# 0                             Primary Night Club
# 1                                        Fox Bar
# 2                                       Deadbolt
# 3                                       Deadbolt
# 4                                       Deadbolt
# ..                                           ...
# 843         Cerise Rooftop, Virgin Hotel Chicago
# 844                                 The Whistler
# 845                                      Arbella
# 846  2117 W Eastwood Ave, Chicago, IL 60625, USA
# 847                                          TBA
#
#                                      club_address  \
# 0         5 W Division St, Chicago, IL 60610, USA
# 1     113 N Green St #125, Chicago, IL 60607, USA
# 2    2412 N Milwaukee Ave, Chicago, IL 60647, USA
# 3    2412 N Milwaukee Ave, Chicago, IL 60647, USA
# 4    2412 N Milwaukee Ave, Chicago, IL 60647, USA
# ..                                            ...
# 843      203 N Wabash Ave, Chicago, IL 60601, USA
# 844  2421 N Milwaukee Ave, Chicago, IL 60647, USA
# 845       112 W Grand Ave, Chicago, IL 60654, USA
# 846   2117 W Eastwood Ave, Chicago, IL 60625, USA
# 847                              Chicago, IL, USA
#
#                    creator_email               modifier_email
# 0         matt@thebloxoffice.com           skhaita2@gmail.com
# 1         matt@thebloxoffice.com           skhaita2@gmail.com
# 2         matt@thebloxoffice.com           skhaita2@gmail.com
# 3         matt@thebloxoffice.com           skhaita2@gmail.com
# 4         matt@thebloxoffice.com           skhaita2@gmail.com
# ..                           ...                          ...
# 843       ryancwilling@gmail.com       ryancwilling@gmail.com
# 844       matt@thebloxoffice.com       matt@thebloxoffice.com
# 845  maxjacobson.music@gmail.com  maxjacobson.music@gmail.com
# 846     djmaterial.chi@gmail.com       matt@thebloxoffice.com
# 847        delaluzardb@gmail.com        delaluzardb@gmail.com
#
# [848 rows x 31 columns]

# %% [markdown]
# ## Set up Superlinked

# %%
@schema
class EventSchema:
    id: IdField
    date_created: Timestamp
    date_modified: Timestamp
    slug: String
    date: Timestamp
    age_limit: Integer
    image: String
    description: String
    time1: String
    time2: String
    private: String
    venue_undisclosed: String
    title: String
    release_date: Timestamp
    white_label_only: String
    artist_names: String
    promoter_names: String
    organization_names: String
    club_name: String
    club_address: String
    creator_email: String
    modifier_email: String

# %%
print(EventSchema)
print(event)
print(description_space)
print(event_index)
# Out:
# <class 'superlinked.framework.common.schema.schema.DecoratedType'>
# <superlinked.framework.common.schema.schema.DecoratedType object at 0x7909d4487070>
# <superlinked.framework.dsl.space.text_similarity_space.TextSimilaritySpace object at 0x7909d44b3a60>
# <superlinked.framework.dsl.index.index.Index object at 0x790ac8c1e1a0>

# %%
event = EventSchema()

# %%
description_space = TextSimilaritySpace(text=event.description, model=MODEL)
title_space = TextSimilaritySpace(text=event.title, model=MODEL)
artist_space = TextSimilaritySpace(text=event.artist_names, model=MODEL)
promoter_space = TextSimilaritySpace(text=event.promoter_names, model=MODEL)
venue_space = TextSimilaritySpace(text=event.club_name, model=MODEL)
recency_space = RecencySpace(timestamp=event.date, period_time_param_list=[
    PeriodTimeParam(16 * YEAR_IN_DAYS, negative_filter=0),
    PeriodTimeParam(40 * YEAR_IN_DAYS, negative_filter=0),
    PeriodTimeParam(160 * YEAR_IN_DAYS, negative_filter=0)
])

# %%
event_index = Index(spaces=[description_space, title_space, artist_space, promoter_space, venue_space, recency_space])
# Out:
# .gitattributes:   0%|          | 0.00/690 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.01k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/69.6M [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/314 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
advanced_query = (
    Query(event_index, weights={
        description_space: Param("description_weight"),
        title_space: Param("title_weight"),
        artist_space: Param("artist_weight"),
        promoter_space: Param("promoter_weight"),
        venue_space: Param("venue_weight"),
        recency_space: Param("recency_weight")
    })
    .find(event)
    .similar(description_space.text, Param("description_query_text"))
    .similar(title_space.text, Param("title_query_text"))
    .similar(artist_space.text, Param("artist_query_text"))
    .similar(promoter_space.text, Param("promoter_query_text"))
    .similar(venue_space.text, Param("venue_query_text"))
)

# %%
df_parser = DataFrameParser(schema=event)

# %%
source: InMemorySource = InMemorySource(event, parser=df_parser)
executor: InMemoryExecutor = InMemoryExecutor(sources=[source], indices=[event_index])
app: InMemoryApp = executor.run()

# %%
source.put([event_df])

# %% [markdown]
# ## Run queries

# %% [markdown]
# ### Queries

# %% [markdown]
# With the simple query, I can search with my text in all of the fields

# %%
# result: Result = app.query(
#     simple_query,
#     query_text="Sci-fi epic action film",
#     description_weight=1,
#     title_weight=1,
#     genre_weight=1,
#     recency_weight=0
# )
# parse_results(result, movie_df, 10)

# %% [markdown]
# With the advanced query, I can supply different search terms for each attribute of the event.

# %%
result = app.query(
    advanced_query,
    description_query_text="",
    title_query_text="",
    artist_query_text="lesprite",
    promoter_query_text="",
    venue_query_text="arbella",
    description_weight=0,
    title_weight=0,
    artist_weight=10,
    promoter_weight=0,
    venue_weight=10,
    recency_weight=-15,
)
parse_results(result, event_df, 3)
# Out:
#      date_created  date_modified  \
# id
# 957  1.683852e+09   1.683852e+09
# 7    1.568033e+09   1.583939e+09
# 190  1.557408e+09   1.591714e+09
#
#                                               slug          date  age_limit  \
# id
# 957                       lesprite-nite-at-arbella  1.683936e+09         21
# 7    deep-grooves-iv-in-support-of-for-real-spaces  1.571357e+09         21
# 190                               deep-grooves-iii  1.562112e+09         21
#
#                                         image  venue_id  \
# id
# 957  e868e4b8-2cd1-4238-aac2-8f76eb594b7f.jpg        50
# 7        6675a8723fa80cebdc53c0eeb3cf08f8.jpg        50
# 190      91c314017cafb5f0de20f4b61dcd5a73.jpg        50
#
#                                            description     time1     time2  \
# id
# 957                                                     22:00:00  03:00:00
# 7    Deep Grooves is back for its 4th edition, now ...  17:00:00  01:30:00
# 190  A night of deep, soulful, punchy grooves in th...  22:00:00  01:30:00
#
#      ...  last_modifier_id white_label_only  deleted  \
# id   ...
# 957  ...              7865            False    False
# 7    ...                 2            False    False
# 190  ...                 2            False    False
#
#                                           artist_names      promoter_names  \
# id
# 957                 Brown Sugar, Flower Food, Lesprite
# 7    Beaux, Cope, Desadeca, JRynecki, Liam Wells, M...
# 190           Desadeca, JRynecki b2b Cyric, Liam Wells  Abound Productions
#
#           organization_names club_name  \
# id
# 957                  XXXXXXX   Arbella
# 7         Abound Productions   Arbella
# 190  Abound Productions temp   Arbella
#
#                                 club_address           creator_email  \
# id
# 957  112 W Grand Ave, Chicago, IL 60654, USA  matt@thebloxoffice.com
# 7    112 W Grand Ave, Chicago, IL 60654, USA  matt@thebloxoffice.com
# 190  112 W Grand Ave, Chicago, IL 60654, USA  matt@thebloxoffice.com
#
#              modifier_email
# id
# 957  matt@thebloxoffice.com
# 7        skhaita2@gmail.com
# 190      skhaita2@gmail.com
#
# [3 rows x 30 columns]
#      date_created  date_modified  \
# id
# 957  1.683852e+09   1.683852e+09
# 7    1.568033e+09   1.583939e+09
# 190  1.557408e+09   1.591714e+09
#
#                                               slug          date  age_limit  \
# id
# 957                       lesprite-nite-at-arbella  1.683936e+09         21
# 7    deep-grooves-iv-in-support-of-for-real-spaces  1.571357e+09         21
# 190                               deep-grooves-iii  1.562112e+09         21
#
#                                         image  venue_id  \
# id
# 957  e868e4b8-2cd1-4238-aac2-8f76eb594b7f.jpg        50
# 7        6675a8723fa80cebdc53c0eeb3cf08f8.jpg        50
# 190      91c314017cafb5f0de20f4b61dcd5a73.jpg        50
#
#                                            description     time1     time2  \
# id
# 957                                                     22:00:00  03:00:00
# 7    Deep Grooves is back for its 4th edition, now ...  17:00:00  01:30:00
# 190  A night of deep, soulful, punchy grooves in th...  22:00:00  01:30:00
#
#      ...  white_label_only deleted  \
# id   ...
# 957  ...             False   False
# 7    ...             False   False
# 190  ...             False   False
#
#                                           artist_names      promoter_names  \
# id
# 957                 Brown Sugar, Flower Food, Lesprite
# 7    Beaux, Cope, Desadeca, JRynecki, Liam Wells, M...
# 190           Desadeca, JRynecki b2b Cyric, Liam Wells  Abound Productions
#
#           organization_names  club_name  \
# id
# 957                  XXXXXXX    Arbella
# 7         Abound Productions    Arbella
# 190  Abound Productions temp    Arbella
#
#                                 club_address           creator_email  \
# id
# 957  112 W Grand Ave, Chicago, IL 60654, USA  matt@thebloxoffice.com
# 7    112 W Grand Ave, Chicago, IL 60654, USA  matt@thebloxoffice.com
# 190  112 W Grand Ave, Chicago, IL 60654, USA  matt@thebloxoffice.com
#
#              modifier_email  order
# id
# 957  matt@thebloxoffice.com      1
# 7        skhaita2@gmail.com      2
# 190      skhaita2@gmail.com      3
#
# [3 rows x 31 columns]
